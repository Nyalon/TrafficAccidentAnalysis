# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import os
import json
import sys
sys.path.insert(0, 'Data')
from config import g_key

#Store Part I results into DataFrame
#Load the data to a DataFrame
accident_data = pd.read_csv("Data/accident_data.csv", encoding="utf-8")
accident_data.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
#   Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False          False        False          Night          Night
# 1           False          False        False          Night          Night
# 2           False           True        False          Night          Night
# 3           False          False        False          Night            Day
# 4           False           True        False            Day            Day
#
#   Nautical_Twilight Astronomical_Twilight
# 0             Night                 Night
# 1             Night                   Day
# 2               Day                   Day
# 3               Day                   Day
# 4               Day                   Day
#
# [5 rows x 49 columns]

# %%
# Data cleanup

# Filters out dates containing 2016, 2017, & 2019 -- too much data in dataset to handle with laptops
accident_data_revised = accident_data[~accident_data["Start_Time"].str.contains("2016")]
accident_data_revised = accident_data_revised[~accident_data_revised["Start_Time"].str.contains("2017")]
accident_data_revised = accident_data_revised[~accident_data_revised["Start_Time"].str.contains("2019")]

# Splits the Start_Time column into individual columns
accident_data_revised[["Date", "Time"]] = accident_data_revised["Start_Time"].str.split(expand=True)

# Renames columns to be more readable
accident_data_revised = accident_data_revised.rename(columns={"Start_Lat":"Lat", "Start_Lng":"Lng", "Weather_Condition":"Weather"})

# Filters and rearranges dataset to display most useful columns
accident_data_revised = accident_data_revised[["Date", "Time", "Lat", "Lng", "City", "State",
         "County", "Weather", "Temperature(F)", "Severity", "Nautical_Twilight"]]

# Iterates through all column data to find NaN values and adds them to a list
accident_data_revised.columns[accident_data_revised.isna().any()].tolist()

accident_data_revised = accident_data_revised.reset_index()

accident_data_revised.head(20)
# Out:
#      index        Date      Time        Lat         Lng                City  \
# 0   626043  2018-12-31  23:54:51  40.740047  -73.818512            Flushing
# 1   626045  2018-12-31  22:40:11  40.834370  -73.864113               Bronx
# 2   626355  2018-12-31  12:35:54  38.441975  -88.953049                 Dix
# 3   626407  2018-12-31  22:32:27  30.241417  -97.726158              Austin
# 4   626462  2018-12-31  23:49:55  32.773060  -96.744247              Dallas
# 5   626463  2018-12-31  23:49:24  32.818420  -96.802391              Dallas
# 6   626563  2018-12-31  18:46:51  39.902153 -104.988914              Denver
# 7   626574  2018-12-31  22:26:47  32.192139 -110.857933              Tucson
# 8   626599  2018-12-31  22:40:29  35.008537 -105.664352            Moriarty
# 9   626602  2018-12-31  22:37:23  35.423836 -108.312744  Continental Divide
# 10  626614  2018-12-31  21:54:47  44.436577 -121.939568          Blue River
# 11  626617  2018-12-31  21:52:39  47.624599 -122.341049             Seattle
# 12  626618  2018-12-31  22:51:14  47.595825 -122.312325             Seattle
# 13  626630  2018-12-31  21:53:04  45.383381 -122.751442            Tualatin
# 14  626631  2018-12-31  23:03:09  45.479259 -122.568611            Portland
# 15  626632  2018-12-31  23:14:48  45.664291 -123.164368               Banks
# 16  626658  2018-12-31  18:18:43  37.686577 -121.057480             Modesto
# 17  626659  2018-12-31  21:17:08  37.689190 -122.135651         San Leandro
# 18  626660  2018-12-31  20:35:32  38.233925 -121.280701                Galt
# 19  626661  2018-12-31  19:34:02  39.198746 -121.012215        Grass Valley
#
#    State       County        Weather  Temperature(F)  Severity  \
# 0     NY       Queens     Heavy Rain            46.9         3
# 1     NY        Bronx           Rain            46.4         3
# 2     IL    Jefferson     Light Rain            57.0         3
# 3     TX       Travis  Partly Cloudy            39.9         2
# 4     TX       Dallas          Clear            43.0         2
# 5     TX       Dallas          Clear            43.0         2
# 6     CO        Adams           Snow             8.6         3
# 7     AZ         Pima     Light Rain            37.4         2
# 8     NM     Torrance     Light Snow            27.9         3
# 9     NM     McKinley     Light Snow            25.0         3
# 10    OR         Linn          Clear            35.1         2
# 11    WA         King  Mostly Cloudy            34.0         2
# 12    WA         King          Clear            33.1         2
# 13    OR   Washington          Clear            35.1         3
# 14    OR    Multnomah  Partly Cloudy            32.0         2
# 15    OR   Washington          Clear            28.9         2
# 16    CA   Stanislaus          Clear            48.9         2
# 17    CA      Alameda          Clear            52.0         3
# 18    CA  San Joaquin          Clear            46.0         2
# 19    CA       Nevada          Clear            33.8         2
#
#    Nautical_Twilight
# 0              Night
# 1              Night
# 2                Day
# 3              Night
# 4              Night
# 5              Night
# 6              Night
# 7              Night
# 8              Night
# 9              Night
# 10             Night
# 11             Night
# 12             Night
# 13             Night
# 14             Night
# 15             Night
# 16             Night
# 17             Night
# 18             Night
# 19             Night

# %%
# Combine Lat/Lng and City/State
accident_data_revised['Coordinates'] = accident_data_revised['Lat'].astype(str).str.zfill(2) + ', ' + accident_data_revised['Lng'].astype(str).str.zfill(3)

accident_data_revised['Location'] = accident_data_revised['City'] + ", " + accident_data_revised['State']
accident_data_revised.head()
# Out:
#     index        Date      Time        Lat        Lng      City State  \
# 0  626043  2018-12-31  23:54:51  40.740047 -73.818512  Flushing    NY
# 1  626045  2018-12-31  22:40:11  40.834370 -73.864113     Bronx    NY
# 2  626355  2018-12-31  12:35:54  38.441975 -88.953049       Dix    IL
# 3  626407  2018-12-31  22:32:27  30.241417 -97.726158    Austin    TX
# 4  626462  2018-12-31  23:49:55  32.773060 -96.744247    Dallas    TX
#
#       County        Weather  Temperature(F)  Severity Nautical_Twilight  \
# 0     Queens     Heavy Rain            46.9         3             Night
# 1      Bronx           Rain            46.4         3             Night
# 2  Jefferson     Light Rain            57.0         3               Day
# 3     Travis  Partly Cloudy            39.9         2             Night
# 4     Dallas          Clear            43.0         2             Night
#
#              Coordinates      Location
# 0  40.740047, -73.818512  Flushing, NY
# 1   40.83437, -73.864113     Bronx, NY
# 2  38.441975, -88.953049       Dix, IL
# 3  30.241417, -97.726158    Austin, TX
# 4   32.77306, -96.744247    Dallas, TX

# %%
# Add column to dataframe showing frequency of accidents at specific coordinates
accident_data_revised['frequency'] = accident_data_revised['Coordinates'].map(accident_data_revised['Coordinates'].value_counts())
accident_data_revised.head()
# Out:
#     index        Date      Time        Lat        Lng      City State  \
# 0  626043  2018-12-31  23:54:51  40.740047 -73.818512  Flushing    NY
# 1  626045  2018-12-31  22:40:11  40.834370 -73.864113     Bronx    NY
# 2  626355  2018-12-31  12:35:54  38.441975 -88.953049       Dix    IL
# 3  626407  2018-12-31  22:32:27  30.241417 -97.726158    Austin    TX
# 4  626462  2018-12-31  23:49:55  32.773060 -96.744247    Dallas    TX
#
#       County        Weather  Temperature(F)  Severity Nautical_Twilight  \
# 0     Queens     Heavy Rain            46.9         3             Night
# 1      Bronx           Rain            46.4         3             Night
# 2  Jefferson     Light Rain            57.0         3               Day
# 3     Travis  Partly Cloudy            39.9         2             Night
# 4     Dallas          Clear            43.0         2             Night
#
#              Coordinates      Location  frequency
# 0  40.740047, -73.818512  Flushing, NY          1
# 1   40.83437, -73.864113     Bronx, NY          3
# 2  38.441975, -88.953049       Dix, IL          1
# 3  30.241417, -97.726158    Austin, TX          1
# 4   32.77306, -96.744247    Dallas, TX          1

# %%
# Which coordinates had the most severe accidents?
# Filter all rows for which severity is greater than or equal to 3
accident_data_revised_filtered = accident_data_revised[accident_data_revised['Severity'] >= 3] 
accident_data_revised_filtered.head()
# Out:
#     index        Date      Time        Lat         Lng      City State  \
# 0  626043  2018-12-31  23:54:51  40.740047  -73.818512  Flushing    NY
# 1  626045  2018-12-31  22:40:11  40.834370  -73.864113     Bronx    NY
# 2  626355  2018-12-31  12:35:54  38.441975  -88.953049       Dix    IL
# 6  626563  2018-12-31  18:46:51  39.902153 -104.988914    Denver    CO
# 8  626599  2018-12-31  22:40:29  35.008537 -105.664352  Moriarty    NM
#
#       County     Weather  Temperature(F)  Severity Nautical_Twilight  \
# 0     Queens  Heavy Rain            46.9         3             Night
# 1      Bronx        Rain            46.4         3             Night
# 2  Jefferson  Light Rain            57.0         3               Day
# 6      Adams        Snow             8.6         3             Night
# 8   Torrance  Light Snow            27.9         3             Night
#
#                       Coordinates      Location  frequency
# 0           40.740047, -73.818512  Flushing, NY          1
# 1            40.83437, -73.864113     Bronx, NY          3
# 2           38.441975, -88.953049       Dix, IL          1
# 6  39.90215300000001, -104.988914    Denver, CO          1
# 8          35.008537, -105.664352  Moriarty, NM          1

# %%
# Which coordinates had the most frequent severe accidents?
# Filter all rows for which frequency is greater than 162
accident_data_most_severe = accident_data_revised_filtered[accident_data_revised_filtered['frequency'] >= 162]
accident_data_most_severe.head()
# Out:
#        index        Date      Time        Lat        Lng        City State  \
# 789   685846  2018-11-30  12:58:02  35.825504 -78.621483     Raleigh    NC
# 815   685872  2018-11-30  15:24:31  35.814922 -78.605362     Raleigh    NC
# 891   685948  2018-11-30  22:05:03  35.825504 -78.621483     Raleigh    NC
# 1061  686118  2018-11-30  07:58:57  34.833031 -82.296837  Greenville    SC
# 1062  686119  2018-11-30  07:59:16  34.858925 -82.259857  Greenville    SC
#
#           County        Weather  Temperature(F)  Severity Nautical_Twilight  \
# 789         Wake  Mostly Cloudy            64.9         3               Day
# 815         Wake  Mostly Cloudy            64.9         3               Day
# 891         Wake     Light Rain            57.0         3             Night
# 1061  Greenville     Light Rain            50.0         3               Day
# 1062  Greenville     Light Rain            50.0         3               Day
#
#                         Coordinates        Location  frequency
# 789   35.82550399999999, -78.621483     Raleigh, NC        172
# 815           35.814922, -78.605362     Raleigh, NC        189
# 891   35.82550399999999, -78.621483     Raleigh, NC        172
# 1061          34.833031, -82.296837  Greenville, SC        285
# 1062          34.858925, -82.259857  Greenville, SC        324

# %%
# Find unique coordinates per severity (this will delete some rows of data)
you_will_prob_die_here = accident_data_most_severe.drop_duplicates(subset=['Location'])
you_will_prob_die_here
# Out:
#         index        Date      Time        Lat         Lng           City  \
# 789    685846  2018-11-30  12:58:02  35.825504  -78.621483        Raleigh
# 1061   686118  2018-11-30  07:58:57  34.833031  -82.296837     Greenville
# 1183   686240  2018-11-30  19:16:43  33.744976  -84.390343        Atlanta
# 2730   687787  2018-11-30  09:32:40  33.941364 -118.096634         Downey
# 4108   689165  2018-12-02  18:05:17  30.422909  -91.139572    Baton Rouge
# 4688   689745  2018-12-03  20:32:53  40.850067  -73.944817       New York
# 5517   690574  2018-12-03  17:30:32  33.978249  -81.195084      Lexington
# 5549   690606  2018-12-03  19:26:45  34.039364  -81.093620       Columbia
# 6747   691804  2018-12-03  08:36:33  37.808498 -122.366852  San Francisco
# 54789  739846  2018-10-31  17:20:09  44.966118  -93.269920    Minneapolis
#
#       State            County        Weather  Temperature(F)  Severity  \
# 789      NC              Wake  Mostly Cloudy            64.9         3
# 1061     SC        Greenville     Light Rain            50.0         3
# 1183     GA            Fulton  Mostly Cloudy            64.9         3
# 2730     CA       Los Angeles  Partly Cloudy            63.0         3
# 4108     LA  East Baton Rouge          Clear            64.0         3
# 4688     NY          New York  Partly Cloudy            48.0         3
# 5517     SC         Lexington  Partly Cloudy            60.1         3
# 5549     SC          Richland  Partly Cloudy            55.9         3
# 6747     CA     San Francisco  Mostly Cloudy            48.9         3
# 54789    MN          Hennepin  Partly Cloudy            53.1         3
#
#       Nautical_Twilight                     Coordinates           Location  \
# 789                 Day   35.82550399999999, -78.621483        Raleigh, NC
# 1061                Day           34.833031, -82.296837     Greenville, SC
# 1183              Night           33.744976, -84.390343        Atlanta, GA
# 2730                Day          33.941364, -118.096634         Downey, CA
# 4108              Night  30.422909000000004, -91.139572    Baton Rouge, LA
# 4688              Night           40.850067, -73.944817       New York, NY
# 5517                Day           33.978249, -81.195084      Lexington, SC
# 5549              Night            34.039364, -81.09362       Columbia, SC
# 6747                Day          37.808498, -122.366852  San Francisco, CA
# 54789               Day            44.966118, -93.26992    Minneapolis, MN
#
#        frequency
# 789          172
# 1061         285
# 1183         206
# 2730         217
# 4108         188
# 4688         180
# 5517         184
# 5549         205
# 6747         223
# 54789        250

# %%
total_rows=len(you_will_prob_die_here.axes[0])
print(total_rows)
# Out:
# 17
